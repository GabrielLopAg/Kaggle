# %%
import pandas as pd
df = pd.read_csv('starts_data.csv', skiprows=2)
df
# Out:
# c:\Users\Gabriel López\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                         0  Unnamed: 1  \
# 0                                                       1         1.0
# 1                                                       2         2.0
# 2                                                       3         3.0
# 3                                                       4         4.0
# 4                                                       5         5.0
# ...                                                   ...         ...
# 119609  119612\t\t\t\tNN 4385\t\t\t23.996567\t47.76209...         NaN
# 119610  119613\t\t\t\tNN 4386\t\t\t23.996218\t-44.0679...         NaN
# 119611  119614\t\t\t\tNN 4387\t\t\t23.997386\t-34.1119...         NaN
# ...

# %%
import csv
i = 0
with open('starts_data.csv', 'r') as bad_data, open('clean_data.csv', 'w', newline = '') as good_data:
    reader = csv.reader(bad_data)
    writer = csv.writer(good_data, delimiter = '|', quoting = csv.QUOTE_ALL)
    # Saltandonos la primera linea 
    next(reader)
    column_names = next(reader)
    column_names = column_names[0].split('~')
    writer.writerow(column_names)
    
    for row in reader:
        # Validando el número de columnas
        # if len(row) != 37:
        #     print(row)

        # Cambiando tabuladores por comas
        if '\t' in row[0]:
            row_string = row[0]
            row_string = row_string.replace('\t', ',')
            row_string = row_string.split(',')
            writer.writerow(row_string)            

        if row[0] == 'Delete me! o_________________o':
            break

        writer.writerow(row)

        # if i >= 119607:
        #     print(row)
        # i += 1
